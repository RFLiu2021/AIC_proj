# %%
# %pylab inline
import scanpy as sc
import pandas as pd
import seaborn as sns
import numpy as np
import scanpy as sc
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
ad_inh = sc.read('./data_h5/Inhib_sorted.h5ad')
ad_inh
# Out:
# AnnData object with n_obs × n_vars = 16364 × 19944
#     obs: 'batch', 'doublet_score', 'predicted_doublets', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden', 'sampleLayers', 'cluster_labels', 'Sex', 'mainMarker'
#     var: 'gene_ids', 'feature_types', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'Sex_colors', 'batch_colors', 'cluster_labels_colors', 'cluster_names', 'hvg', 'leiden', 'leiden_colors', 'mainMarker_colors', 'neighbors', 'pca', 'rank_genes_groups', 'sampleLayers_colors', 'tsne', 'umap'
#     obsm: 'X_harmonypca', 'X_pca', 'X_tsne', 'X_umap', 'X_umapharmony', 'X_umapraw'
#     varm: 'PCs'
#     layers: 'RawCounts'
#     obsp: 'connectivities', 'distances'

# %%
figsize(8,8)
sc.pl.umap(ad_inh, color=['leiden'], legend_loc='on data', title='', frameon=False,use_raw=True,size=15)#, save='InhClusters.pdf')
# Out:
# /home/liu/anaconda3/envs/bioSoft/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
figsize(8,8)
sc.pl.umap(ad_inh, color=['cluster_labels'], legend_loc='on data', title='', frameon=False,use_raw=True,size=15)#, save='InhClustersLabels.pdf')
# Out:
# /home/liu/anaconda3/envs/bioSoft/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
figsize(8,8)
sc.pl.umap(ad_inh, color=['mainMarker'], legend_loc='on data', title='', frameon=False,use_raw=True,size=2, save='InhMainMarkers.pdf')
# Out:
# WARNING: saving figure to file figures/umapInhMainMarkers.pdf
# /home/liu/anaconda3/envs/bioSoft/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
figsize(4,4)
sc.pl.umap(ad_inh,color=['PAX6','PVALB','SST','VIP','LAMP5','ADARB2','SNCG','SERPINF1'], legend_loc='on data', cmap='RdGy_r', size=2)#,save='Inh_markers_umaps.pdf')

# %%
markers = ['GAD1','SCGN','PENK','MME','RGCC','ANXA2','SHISA8','SMOC1','RASL10A','PTK2B','IL13RA1','PVALB','BCAM','CRISPLD1','IGFBP2',
           'COL5A2','GSTM2','BMP2','ARHGAP18','PIK3CG','PDLIM5','SP5','S100A6','ADRA1D','CDH24','SLC30A3','KLHL13','DCN',
           'TPM2','C1QL2','NKX2-1','SERPINF1','CHODL','SLIT1']
sc.pl.stacked_violin(ad_inh, markers, groupby='leiden',swap_axes = True, dendrogram=False,cmap='Reds')#, save = 'inh_stackedVlnPlot.pdf')
